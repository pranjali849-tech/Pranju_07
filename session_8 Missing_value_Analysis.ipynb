# %%
import numpy as np
import pandas as pd
Data={'Names':['Ramesh','Suresh','Satish',np.nan],
      'Age':[np.nan,22,25,27],
      'City':['Pune','Pune',np.nan,'Hyd']}

df=pd.DataFrame(Data)
df
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   NaN
# 3     NaN  27.0   Hyd

# %%
Data1={'Name':['Ramesh','Suresh','Ramesh',None],
       'Age':[None,22,25,27],
       'City':['Pune','Pune',None,'Hyd']}
df1=pd.DataFrame(Data1)
df1
# Out:
#      Name   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Ramesh  25.0  None
# 3    None  27.0   Hyd

# %%
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   NaN
# 3     NaN  27.0   Hyd

# %%
df.dtypes
# Out:
# Names     object
# Age      float64
# City      object
# dtype: object

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   NaN
# 3     NaN  27.0   Hyd>

# %% [markdown]
# **fillna**

# %%
df.fillna(30)  # Not recomended
# Out:
#     Names   Age  City
# 0  Ramesh  30.0  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0    30
# 3      30  27.0   Hyd

# %%
df1.fillna(30)
# Out:
#      Name   Age  City
# 0  Ramesh  30.0  Pune
# 1  Suresh  22.0  Pune
# 2  Ramesh  25.0    30
# 3      30  27.0   Hyd

# %%
df.fillna('Hyd')
# Out:
#     Names   Age  City
# 0  Ramesh   Hyd  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   Hyd
# 3     Hyd  27.0   Hyd

# %% [markdown]
# df['age'].fillna(30) # error

# %% [markdown]
# - The above one is we are filling randomly
#
# - All the columns are filled with random number
#
# - It is not a good approach because in a data we have different data types

# %% [markdown]
# **What is the difference between np.nan and None**

# %%
np.nan+5
# Out:
# nan

# %%
None+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 None+5
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
arr1=np.array([1,2,np.nan,3])
arr2=np.array([1,2,None,3])

# %%
arr1
# Out:
# array([ 1.,  2., nan,  3.])

# %%
arr2
# Out:
# array([1, 2, None, 3], dtype=object)

# %%
np.nansum(arr1),np.sum(arr1)
# Out:
# (np.float64(6.0), np.float64(nan))

# %%
np.sum(arr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 np.sum(arr2)
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:2485, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2482         return out
#    2483     return res
# -> 2485 return _wrapreduction(
#    2486     a, np.add, 'sum', axis, dtype, out,
#    2487     keepdims=keepdims, initial=initial, where=where
#    2488 )
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# - np.nan represents **float type**
#
# - None represents **Object type**
#
# - if data operations related to Maths then nan format is better

# %% [markdown]
# **Fill the Value based on column**
#
# - Whenever we are using methods no need to provide values

# %%
# df.fillna()
df['Names'].fillna('Manish')
# Out:
# 0    Ramesh
# 1    Suresh
# 2    Satish
# 3    Manish
# Name: Names, dtype: object

# %%
import numpy as np
import pandas as pd
Data={'Names':['Ramesh','Suresh','Satish',np.nan],
      'Age':[np.nan,22,25,27],
      'City':['Pune','Pune',np.nan,'Hyd']}

df=pd.DataFrame(Data)
df
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   NaN
# 3     NaN  27.0   Hyd

# %% [markdown]
# - pad
#
# - bfill
#
# - ffill
#
# - backfill

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='pad')       
# upper value asses lower
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0  Pune
# 3  Satish  27.0   Hyd

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='pad',axis=1)
# Out:
#     Names     Age  City
# 0  Ramesh  Ramesh  Pune
# 1  Suresh    22.0  Pune
# 2  Satish    25.0  25.0
# 3     NaN    27.0   Hyd

# %%
df.fillna(method='bfill')
# l
# Out:
#     Names   Age  City
# 0  Ramesh  22.0  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   Hyd
# 3     NaN  27.0   Hyd

# %%
df.fillna(method='ffill')
# Out:
#     Names   Age  City
# 0  Ramesh   NaN  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0  Pune
# 3  Satish  27.0   Hyd

# %%
df.fillna(method='backfill')
# Out:
#     Names   Age  City
# 0  Ramesh  22.0  Pune
# 1  Suresh  22.0  Pune
# 2  Satish  25.0   Hyd
# 3     NaN  27.0   Hyd

# %% [markdown]
# - Mean-Median-Mode
#
# - we can use mean median and mode also
#
# - For Numerical columns use mean and Median
#
#      - if Data outliers are there use **Median**
#
# - For categorical columns use **Mode**

# %%
# first calculate median
# Then fill with median
age_median=df['Age'].median()
df['Age'].fillna(age_median)
# Out:
# 0    25.0
# 1    22.0
# 2    25.0
# 3    27.0
# Name: Age, dtype: float64

# %%
age_median
# Out:
# 25.0

# %%
round(df['Age']).median
# Out:
# <bound method Series.median of 0     NaN
# 1    22.0
# 2    25.0
# 3    27.0
# Name: Age, dtype: float64>

# %%
mode=df['City'].mode()
mode
# Out:
# 0    Pune
# Name: City, dtype: object

# %%
mode=df[

# %% [markdown]
# **KNN Imputer**

# %% [markdown]
# - K-Nearest Neighbours
#
# - Where k=hyper parameter which means the user can change
#
# - Idea : Instead of taking all the samples averages
#
#     - First fix the neighbours number i.e.k
#
#     - Then find the neighbours using distance metric
#
#     - Then take the average of those samepls to fill the missing value

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
pd.DataFrame(X)
# Out:
#      0     1    2
# 0  1.0   2.0  NaN
# 1  3.0   NaN  3.0
# 2  NaN  60.0  5.0
# 3  8.0   8.0  7.0

# %%
import numpy as np
from sklearn.impute import KNNImputer
X=[[1,2,np.nan],[3,np.nan,3],
   [np.nan,60,5],[8,8,7]]
imputer=KNNImputer(n_neighbors=2,
                    weights='uniform')
imputer.fit_transform(X)
# Out:
# array([[ 1. ,  2. ,  5. ],
#        [ 3. , 31. ,  3. ],
#        [ 5.5, 60. ,  5. ],
#        [ 8. ,  8. ,  7. ]])

# %%
import numpy as np
from sklearn.impute import KNNIputer
X=[[1,2,np.nan],[3,np.nan,3],
   [np.nan,60,5],[8,8,7]]

imputer=KNNImputer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 2
#       1 import numpy as np
# ----> 2 from sklearn.impute import KNNIputer
#       3 X=[[1,2,np.nan],[3,np.nan,3],
#       4    [np.nan,60,5],[8,8,7]]
#       6 imputer=KNNImputer
#
# ImportError: cannot import name 'KNNIputer' from 'sklearn.impute' (C:\Users\Hp\anaconda3\Lib\site-packages\sklearn\impute\__init__.py)
